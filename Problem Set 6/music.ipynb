# %%
class Music:
    
    def __init__(self, name, time):
        self.__minutes__ = int(time[0:2])
        self.__seconds__ = int(time[3:0])
        self.__time__ = time
        self.__name__ = name 
        
        
    def getName(self):
        return self.__name__
    
    def getTime(self):
        return self.__time__
    
    def getMinutes(self):
        return self.__minutes__ 
    
    def getSeconds(self):
        return self.__seconds__
    
    
class Album:
    
    def __init__(self, title, artist, date):
        self.__title__ = title
        self.__artist__ = artist
        self.__date__ = date
        self.__songs__ = []
        
    def getTitle(self):
        return self.__title__
    
    def getArtist(self):
        return self.__artist__
    
    def getDate(self):
        return self.__date__
     
    def addSongs(self,song):
        self.__songs__.append(song)
    
    def getSong(self):
        return self.__songs__
    
    def getTotalLength(self):
        total = 0
        for songs in self.__songs__:
            total += music.getMinutes() + music.getSeconds()
        
    
def main():
    album = input("Enter name of album: ")
    artist_name = input("Enter the name of the artist: ")
    year = input("Enter the release date: ")
    album1 = Album(album, artist_name, year)
    
    number = int(input("How many songs are there: "))
    for songs in range(number):
        song_name = input("Enter the name of the song: ")
        length = input("Enter the length of the song (mm:ss): ")
        album1.addSongs(Music(song_name, length))
        
        
main()
